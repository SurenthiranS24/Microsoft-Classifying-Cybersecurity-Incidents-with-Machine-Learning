# %%
! pip install nltk
! pip install pandas openpyxl
# Out:
# Requirement already satisfied: nltk in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\surenthiran\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\surenthiran\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\surenthiran\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import string
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns
import dask.dataframe as dd
import dask.array as da
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Load the data**

# %%
import pandas as pd
# Local directory
train_data = pd.read_csv('C:/Users/Surenthiran/Desktop/Cybersecurity Incidents/GUIDE_Train.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 # Local directory
# ----> 3 train_data = pd.read_csv('C:/Users/Surenthiran/Desktop/Cybersecurity Incidents/GUIDE_Train.csv')
#
# File c:\Users\Surenthiran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Surenthiran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\Surenthiran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1968, in TextFileReader.read(self, nrows)
#    1965     else:
#    1966         new_col_dict = col_dict
# -> 1968     df = DataFrame(
#    1969         new_col_dict,
#    1970         columns=columns,
#    1971         index=index,
#    1972         copy=not using_copy_on_write(),
#    1973     )
#    1975     self._currow += new_rows
#    1976 return df
#
# File c:\Users\Surenthiran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\Surenthiran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\Surenthiran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:152, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     149 axes = [columns, index]
#     151 if typ == "block":
# --> 152     return create_block_manager_from_column_arrays(
#     153         arrays, axes, consolidate=consolidate, refs=refs
#     154     )
#     155 elif typ == "array":
#     156     return ArrayManager(arrays, [index, columns])
#
# File c:\Users\Surenthiran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:2144, in create_block_manager_from_column_arrays(arrays, axes, consolidate, refs)
#    2142     raise_construction_error(len(arrays), arrays[0].shape, axes, e)
#    2143 if consolidate:
# -> 2144     mgr._consolidate_inplace()
#    2145 return mgr
#
# File c:\Users\Surenthiran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1788, in BlockManager._consolidate_inplace(self)
#    1782 def _consolidate_inplace(self) -> None:
#    1783     # In general, _consolidate_inplace should only be called via
#    1784     #  DataFrame._consolidate_inplace, otherwise we will fail to invalidate
#    1785     #  the DataFrame's _item_cache. The exception is for newly-created
#    1786     #  BlockManager objects not yet attached to a DataFrame.
#    1787     if not self.is_consolidated():
# -> 1788         self.blocks = _consolidate(self.blocks)
#    1789         self._is_consolidated = True
#    1790         self._known_consolidated = True
#
# File c:\Users\Surenthiran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:2269, in _consolidate(blocks)
#    2267 new_blocks: list[Block] = []
#    2268 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2269     merged_blocks, _ = _merge_blocks(
#    2270         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2271     )
#    2272     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2273 return tuple(new_blocks)
#
# File c:\Users\Surenthiran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:2304, in _merge_blocks(blocks, dtype, can_consolidate)
#    2301     new_values = new_values[argsort]
#    2302     new_mgr_locs = new_mgr_locs[argsort]
# -> 2304     bp = BlockPlacement(new_mgr_locs)
#    2305     return [new_block_2d(new_values, placement=bp)], True
#    2307 # can't consolidate --> no merge
#
# KeyboardInterrupt:

# %%
train_data.shape
# Out:
# (9516837, 45)

# %%
train_data.head()
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0   180388628218      0         612   123247  2024-06-04T06:05:15.000Z
# 1   455266534868     88         326   210035  2024-06-14T03:01:25.000Z
# 2  1056561957389    809       58352   712507  2024-06-13T04:52:55.000Z
# 3  1279900258736     92       32992   774301  2024-06-10T16:39:36.000Z
# 4   214748368522    148        4359   188041  2024-06-15T01:08:07.000Z
#
#    DetectorId  AlertTitle           Category MitreTechniques   IncidentGrade  \
# 0           7           6      InitialAccess             NaN    TruePositive
# 1          58          43       Exfiltration             NaN   FalsePositive
# 2         423         298      InitialAccess           T1189   FalsePositive
# 3           2           2  CommandAndControl             NaN  BenignPositive
# 4           9          74          Execution             NaN    TruePositive
#
#    ... ResourceType Roles OSFamily OSVersion  AntispamDirection  \
# 0  ...          NaN   NaN        5        66                NaN
# 1  ...          NaN   NaN        5        66                NaN
# 2  ...          NaN   NaN        5        66                NaN
# 3  ...          NaN   NaN        5        66                NaN
# 4  ...          NaN   NaN        5        66                NaN
#
#    SuspicionLevel  LastVerdict  CountryCode  State   City
# 0             NaN          NaN           31      6      3
# 1             NaN          NaN          242   1445  10630
# 2      Suspicious   Suspicious          242   1445  10630
# 3      Suspicious   Suspicious          242   1445  10630
# 4             NaN          NaN          242   1445  10630
#
# [5 rows x 45 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9516837 entries, 0 to 9516836
# Data columns (total 45 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  int64
#  1   OrgId               int64
#  2   IncidentId          int64
#  3   AlertId             int64
#  4   Timestamp           object
#  5   DetectorId          int64
#  6   AlertTitle          int64
#  7   Category            object
#  8   MitreTechniques     object
#  9   IncidentGrade       object
#  10  ActionGrouped       object
#  11  ActionGranular      object
#  12  EntityType          object
#  13  EvidenceRole        object
#  14  DeviceId            int64
#  15  Sha256              int64
#  16  IpAddress           int64
#  17  Url                 int64
#  18  AccountSid          int64
#  19  AccountUpn          int64
#  20  AccountObjectId     int64
#  21  AccountName         int64
#  22  DeviceName          int64
#  23  NetworkMessageId    int64
#  24  EmailClusterId      float64
#  25  RegistryKey         int64
#  26  RegistryValueName   int64
#  27  RegistryValueData   int64
#  28  ApplicationId       int64
#  29  ApplicationName     int64
#  30  OAuthApplicationId  int64
#  31  ThreatFamily        object
#  32  FileName            int64
#  33  FolderPath          int64
#  34  ResourceIdName      int64
#  35  ResourceType        object
#  36  Roles               object
#  37  OSFamily            int64
#  38  OSVersion           int64
#  39  AntispamDirection   object
#  40  SuspicionLevel      object
#  41  LastVerdict         object
#  42  CountryCode         int64
#  43  State               int64
#  44  City                int64
# dtypes: float64(1), int64(30), object(14)
# memory usage: 3.2+ GB

# %%
train_data.describe().transpose()
# Out:
#                         count          mean           std       min  \
# Id                  9516837.0  8.425494e+11  4.962499e+11       0.0
# OrgId               9516837.0  1.815800e+02  3.867784e+02       0.0
# IncidentId          9516837.0  7.066349e+04  1.208369e+05       0.0
# AlertId             9516837.0  4.065188e+05  4.592827e+05       0.0
# DetectorId          9516837.0  1.106724e+02  4.351038e+02       0.0
# AlertTitle          9516837.0  2.947315e+03  1.146150e+04       0.0
# DeviceId            9516837.0  9.566476e+04  1.635288e+04       0.0
# Sha256              9516837.0  1.287191e+05  3.399208e+04       0.0
# IpAddress           9516837.0  2.857506e+05  1.412240e+05       0.0
# Url                 9516837.0  1.503317e+05  3.750795e+04       0.0
# AccountSid          9516837.0  3.524466e+05  1.664965e+05       0.0
# AccountUpn          9516837.0  4.643773e+05  2.902275e+05       0.0
# AccountObjectId     9516837.0  3.409622e+05  1.599377e+05       0.0
# AccountName         9516837.0  3.569664e+05  1.744466e+05       0.0
# DeviceName          9516837.0  1.432298e+05  3.607056e+04       0.0
# NetworkMessageId    9516837.0  4.800467e+05  1.417584e+05       0.0
# EmailClusterId        96812.0  3.242503e+09  1.034468e+09  192708.0
# RegistryKey         9516837.0  1.628170e+03  6.675012e+01       0.0
# RegistryValueName   9516837.0  6.347345e+02  1.258111e+01       0.0
# RegistryValueData   9516837.0  8.595601e+02  1.886303e+01       0.0
# ApplicationId       9516837.0  2.200910e+03  3.315528e+02       0.0
# ApplicationName     9516837.0  3.342790e+03  5.103381e+02       0.0
# OAuthApplicationId  9516837.0  8.807955e+02  1.291083e+01       0.0
# FileName            9516837.0  2.622621e+05  8.152956e+04       0.0
# FolderPath          9516837.0  1.076172e+05  3.220835e+04       0.0
# ResourceIdName      9516837.0  3.583477e+03  9.020262e+01       0.0
# OSFamily            9516837.0  4.898537e+00  7.035099e-01       0.0
# OSVersion           9516837.0  6.465558e+01  9.314929e+00       0.0
# CountryCode         9516837.0  2.236742e+02  6.279729e+01       0.0
# State               9516837.0  1.351488e+03  3.509808e+02       0.0
# City                9516837.0  9.936183e+03  2.606812e+03       0.0
#
#                              25%           50%           75%           max
# Id                  4.123169e+11  8.418136e+11  1.271310e+12  1.709397e+12
# OrgId               1.000000e+01  4.500000e+01  1.710000e+02  6.147000e+03
# IncidentId          5.040000e+02  1.033600e+04  8.432900e+04  5.997060e+05
# AlertId             2.324200e+04  2.166520e+05  6.715770e+05  1.721456e+06
# DetectorId          2.000000e+00  9.000000e+00  4.500000e+01  9.522000e+03
# AlertTitle          2.000000e+00  1.100000e+01  1.800000e+02  1.131740e+05
# DeviceId            9.879900e+04  9.879900e+04  9.879900e+04  9.879900e+04
# Sha256              1.382680e+05  1.382680e+05  1.382680e+05  1.382680e+05
# IpAddress           3.606060e+05  3.606060e+05  3.606060e+05  3.606060e+05
# Url                 1.603960e+05  1.603960e+05  1.603960e+05  1.603960e+05
# AccountSid          4.413770e+05  4.413770e+05  4.413770e+05  4.413770e+05
# AccountUpn          9.258300e+04  6.739340e+05  6.739340e+05  6.739340e+05
# AccountObjectId     4.258630e+05  4.258630e+05  4.258630e+05  4.258630e+05
# AccountName         4.532970e+05  4.532970e+05  4.532970e+05  4.532970e+05
# DeviceName          1.530850e+05  1.530850e+05  1.530850e+05  1.530850e+05
# NetworkMessageId    5.296440e+05  5.296440e+05  5.296440e+05  5.296440e+05
# EmailClusterId      2.762798e+09  3.504264e+09  4.107006e+09  4.294967e+09
# RegistryKey         1.631000e+03  1.631000e+03  1.631000e+03  1.631000e+03
# RegistryValueName   6.350000e+02  6.350000e+02  6.350000e+02  6.350000e+02
# RegistryValueData   8.600000e+02  8.600000e+02  8.600000e+02  8.600000e+02
# ApplicationId       2.251000e+03  2.251000e+03  2.251000e+03  2.251000e+03
# ApplicationName     3.421000e+03  3.421000e+03  3.421000e+03  3.421000e+03
# OAuthApplicationId  8.810000e+02  8.810000e+02  8.810000e+02  8.810000e+02
# FileName            2.895730e+05  2.895730e+05  2.895730e+05  2.895730e+05
# FolderPath          1.176680e+05  1.176680e+05  1.176680e+05  1.176680e+05
# ResourceIdName      3.586000e+03  3.586000e+03  3.586000e+03  3.586000e+03
# OSFamily            5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# OSVersion           6.600000e+01  6.600000e+01  6.600000e+01  6.600000e+01
# CountryCode         2.420000e+02  2.420000e+02  2.420000e+02  2.420000e+02
# State               1.445000e+03  1.445000e+03  1.445000e+03  1.445000e+03
# City                1.063000e+04  1.063000e+04  1.063000e+04  1.063000e+04

# %%
import pandas as pd
# Local directory
test_data = pd.read_csv('C:/Users/Surenthiran/Desktop/Cybersecurity Incidents/GUIDE_Test.csv')

# %%
test_data.shape
# Out:
# (4147992, 46)

# %%
test_data.head(10)
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0  1245540519230    657       11767    87199  2024-06-04T22:56:27.000Z
# 1  1400159342154      3       91158   632273  2024-06-03T12:58:26.000Z
# 2  1279900255923    145       32247   131719  2024-06-08T03:20:49.000Z
# 3    60129547292    222       15294   917686  2024-06-12T12:07:31.000Z
# 4   515396080539    363        7615     5944  2024-06-06T17:42:05.000Z
# 5   670014899930      0         238   378946  2024-06-06T08:10:50.000Z
# 6  1194000913330    133      105333   732769  2024-06-15T04:06:55.000Z
# 7   678604832796      6        2461     1523  2024-05-26T11:48:38.000Z
# 8   618475292265      7        5177     1815  2024-05-25T17:57:20.000Z
# 9   438086667998    100        7060     9787  2024-06-02T05:46:22.000Z
#
#    DetectorId  AlertTitle            Category  \
# 0         524         563     LateralMovement
# 1           2           2   CommandAndControl
# 2        2932       10807     LateralMovement
# 3           0           0       InitialAccess
# 4          27          18           Discovery
# 5           0           0       InitialAccess
# 6           3           4  SuspiciousActivity
# 7          17        1265              Impact
# 8          21         528              Impact
# 9          72          53              Impact
#
#                    MitreTechniques   IncidentGrade  ...       Roles OSFamily  \
# 0      T1021;T1047;T1105;T1569.002  BenignPositive  ...         NaN        5
# 1                              NaN  BenignPositive  ...         NaN        0
# 2  T1021;T1027.002;T1027.005;T1105  BenignPositive  ...         NaN        5
# 3                  T1078;T1078.004   FalsePositive  ...         NaN        5
# 4                  T1087;T1087.002  BenignPositive  ...  Suspicious        5
# 5                  T1078;T1078.004    TruePositive  ...         NaN        5
# 6                              NaN  BenignPositive  ...         NaN        5
# 7                              NaN  BenignPositive  ...         NaN        5
# 8                              NaN   FalsePositive  ...         NaN        5
# 9                              NaN  BenignPositive  ...         NaN        5
#
#   OSVersion AntispamDirection  SuspicionLevel  LastVerdict  CountryCode  \
# 0        66               NaN      Suspicious   Suspicious          242
# 1         0               NaN      Suspicious   Suspicious          242
# 2        66               NaN      Suspicious   Suspicious          242
# 3        66               NaN             NaN          NaN          242
# 4        66               NaN             NaN          NaN          242
# 5        66               NaN             NaN          NaN          242
# 6        66               NaN      Suspicious   Suspicious          242
# 7        66               NaN             NaN          NaN          242
# 8        66               NaN             NaN          NaN          242
# 9        66               NaN             NaN          NaN          242
#
#    State   City    Usage
# 0   1445  10630  Private
# 1   1445  10630   Public
# 2   1445  10630   Public
# 3   1445  10630   Public
# 4   1445  10630   Public
# 5   1445  10630   Public
# 6   1445  10630  Private
# 7   1445  10630   Public
# 8   1445  10630   Public
# 9   1445  10630   Public
#
# [10 rows x 46 columns]

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4147992 entries, 0 to 4147991
# Data columns (total 46 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  int64
#  1   OrgId               int64
#  2   IncidentId          int64
#  3   AlertId             int64
#  4   Timestamp           object
#  5   DetectorId          int64
#  6   AlertTitle          int64
#  7   Category            object
#  8   MitreTechniques     object
#  9   IncidentGrade       object
#  10  ActionGrouped       object
#  11  ActionGranular      object
#  12  EntityType          object
#  13  EvidenceRole        object
#  14  DeviceId            int64
#  15  Sha256              int64
#  16  IpAddress           int64
#  17  Url                 int64
#  18  AccountSid          int64
#  19  AccountUpn          int64
#  20  AccountObjectId     int64
#  21  AccountName         int64
#  22  DeviceName          int64
#  23  NetworkMessageId    int64
#  24  EmailClusterId      float64
#  25  RegistryKey         int64
#  26  RegistryValueName   int64
#  27  RegistryValueData   int64
#  28  ApplicationId       int64
#  29  ApplicationName     int64
#  30  OAuthApplicationId  int64
#  31  ThreatFamily        object
#  32  FileName            int64
#  33  FolderPath          int64
#  34  ResourceIdName      int64
#  35  ResourceType        object
#  36  Roles               object
#  37  OSFamily            int64
#  38  OSVersion           int64
#  39  AntispamDirection   object
#  40  SuspicionLevel      object
#  41  LastVerdict         object
#  42  CountryCode         int64
#  43  State               int64
#  44  City                int64
#  45  Usage               object
# dtypes: float64(1), int64(30), object(15)
# memory usage: 1.4+ GB

# %%
test_data.describe().transpose()
# Out:
#                         count          mean           std       min  \
# Id                  4147992.0  8.462250e+11  4.923351e+11       1.0
# OrgId               4147992.0  1.756698e+02  3.708729e+02       0.0
# IncidentId          4147992.0  6.780345e+04  1.178736e+05       3.0
# AlertId             4147992.0  4.072191e+05  4.550578e+05       0.0
# DetectorId          4147992.0  1.008391e+02  4.082934e+02       0.0
# AlertTitle          4147992.0  2.529514e+03  1.044138e+04       0.0
# DeviceId            4147992.0  9.575061e+04  1.615628e+04       0.0
# Sha256              4147992.0  1.283939e+05  3.457595e+04       0.0
# IpAddress           4147992.0  2.873898e+05  1.400920e+05       0.0
# Url                 4147992.0  1.504279e+05  3.734754e+04       0.0
# AccountSid          4147992.0  3.532813e+05  1.660976e+05       0.0
# AccountUpn          4147992.0  4.706754e+05  2.885003e+05       0.0
# AccountObjectId     4147992.0  3.419357e+05  1.595671e+05       0.0
# AccountName         4147992.0  3.582316e+05  1.738693e+05       0.0
# DeviceName          4147992.0  1.417392e+05  3.868470e+04       0.0
# NetworkMessageId    4147992.0  4.834652e+05  1.368565e+05       0.0
# EmailClusterId        41707.0  3.231065e+09  1.043861e+09  192708.0
# RegistryKey         4147992.0  1.627532e+03  7.382003e+01       0.0
# RegistryValueName   4147992.0  6.345193e+02  1.721417e+01       0.0
# RegistryValueData   4147992.0  8.592115e+02  2.552240e+01       0.0
# ApplicationId       4147992.0  2.200962e+03  3.313870e+02       0.0
# ApplicationName     4147992.0  3.342993e+03  5.096996e+02       0.0
# OAuthApplicationId  4147992.0  8.808119e+02  1.238317e+01       0.0
# FileName            4147992.0  2.618998e+05  8.208434e+04       0.0
# FolderPath          4147992.0  1.074020e+05  3.260346e+04       0.0
# ResourceIdName      4147992.0  3.583541e+03  9.012124e+01       0.0
# OSFamily            4147992.0  4.899529e+00  7.001299e-01       0.0
# OSVersion           4147992.0  6.466873e+01  9.269678e+00       0.0
# CountryCode         4147992.0  2.222218e+02  6.499822e+01       0.0
# State               4147992.0  1.344570e+03  3.626851e+02       0.0
# City                4147992.0  9.883839e+03  2.696302e+03       0.0
#
#                              25%           50%           75%           max
# Id                  4.209068e+11  8.418136e+11  1.271310e+12  1.709397e+12
# OrgId               8.000000e+00  4.300000e+01  1.730000e+02  6.138000e+03
# IncidentId          4.110000e+02  8.818000e+03  7.944000e+04  5.997000e+05
# AlertId             2.365900e+04  2.228970e+05  6.711010e+05  1.721457e+06
# DetectorId          2.000000e+00  7.000000e+00  3.900000e+01  9.520000e+03
# AlertTitle          2.000000e+00  9.000000e+00  1.160000e+02  1.131690e+05
# DeviceId            9.879900e+04  9.879900e+04  9.879900e+04  9.879900e+04
# Sha256              1.382680e+05  1.382680e+05  1.382680e+05  1.382680e+05
# IpAddress           3.606060e+05  3.606060e+05  3.606060e+05  3.606060e+05
# Url                 1.603960e+05  1.603960e+05  1.603960e+05  1.603960e+05
# AccountSid          4.413770e+05  4.413770e+05  4.413770e+05  4.413770e+05
# AccountUpn          1.015320e+05  6.739340e+05  6.739340e+05  6.739340e+05
# AccountObjectId     4.258630e+05  4.258630e+05  4.258630e+05  4.258630e+05
# AccountName         4.532970e+05  4.532970e+05  4.532970e+05  4.532970e+05
# DeviceName          1.530850e+05  1.530850e+05  1.530850e+05  1.530850e+05
# NetworkMessageId    5.296440e+05  5.296440e+05  5.296440e+05  5.296440e+05
# EmailClusterId      2.688174e+09  3.492818e+09  4.108874e+09  4.294964e+09
# RegistryKey         1.631000e+03  1.631000e+03  1.631000e+03  1.631000e+03
# RegistryValueName   6.350000e+02  6.350000e+02  6.350000e+02  6.350000e+02
# RegistryValueData   8.600000e+02  8.600000e+02  8.600000e+02  8.600000e+02
# ApplicationId       2.251000e+03  2.251000e+03  2.251000e+03  2.251000e+03
# ApplicationName     3.421000e+03  3.421000e+03  3.421000e+03  3.421000e+03
# OAuthApplicationId  8.810000e+02  8.810000e+02  8.810000e+02  8.810000e+02
# FileName            2.895730e+05  2.895730e+05  2.895730e+05  2.895730e+05
# FolderPath          1.176680e+05  1.176680e+05  1.176680e+05  1.176680e+05
# ResourceIdName      3.586000e+03  3.586000e+03  3.586000e+03  3.586000e+03
# OSFamily            5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# OSVersion           6.600000e+01  6.600000e+01  6.600000e+01  6.600000e+01
# CountryCode         2.420000e+02  2.420000e+02  2.420000e+02  2.420000e+02
# State               1.445000e+03  1.445000e+03  1.445000e+03  1.445000e+03
# City                1.063000e+04  1.063000e+04  1.063000e+04  1.063000e+04

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
### Checking Missing values in the Data Set and printing the Percentage for Missing Values for Each Columns ###

count = train_data.isnull().sum().sort_values(ascending=False)
percentage = ((train_data.isnull().sum()/len(train_data)*100)).sort_values(ascending=False)
missing_data = pd.concat([count, percentage], axis=1,
keys=['Count','Percentage'])

print('Count and percentage of missing values for the columns:')

missing_data
# Out:
# Count and percentage of missing values for the columns:
#                       Count  Percentage
# ResourceType        9509762   99.925658
# ActionGrouped       9460773   99.410897
# ActionGranular      9460773   99.410897
# ThreatFamily        9441956   99.213173
# EmailClusterId      9420025   98.982729
# AntispamDirection   9339535   98.136965
# Roles               9298686   97.707736
# SuspicionLevel      8072708   84.825536
# LastVerdict         7282572   76.523030
# MitreTechniques     5468386   57.460120
# IncidentGrade         51340    0.539465
# Timestamp                 0    0.000000
# Id                        0    0.000000
# EntityType                0    0.000000
# DetectorId                0    0.000000
# AlertTitle                0    0.000000
# Category                  0    0.000000
# OrgId                     0    0.000000
# IncidentId                0    0.000000
# AlertId                   0    0.000000
# EvidenceRole              0    0.000000
# AccountObjectId           0    0.000000
# AccountName               0    0.000000
# Sha256                    0    0.000000
# DeviceId                  0    0.000000
# Url                       0    0.000000
# AccountSid                0    0.000000
# AccountUpn                0    0.000000
# IpAddress                 0    0.000000
# ApplicationId             0    0.000000
# RegistryValueData         0    0.000000
# RegistryValueName         0    0.000000
# RegistryKey               0    0.000000
# NetworkMessageId          0    0.000000
# DeviceName                0    0.000000
# FileName                  0    0.000000
# ApplicationName           0    0.000000
# FolderPath                0    0.000000
# ResourceIdName            0    0.000000
# OAuthApplicationId        0    0.000000
# OSVersion                 0    0.000000
# OSFamily                  0    0.000000
# CountryCode               0    0.000000
# State                     0    0.000000
# City                      0    0.000000

# %%
### Checking Missing values in the Data Set and printing the Percentage for Missing Values for Each Columns ###

count = test_data.isnull().sum().sort_values(ascending=False)
percentage = ((test_data.isnull().sum()/len(test_data)*100)).sort_values(ascending=False)
missing_data = pd.concat([count, percentage], axis=1,
keys=['Count','Percentage'])

print('Count and percentage of missing values for the columns:')

missing_data
# Out:
# Count and percentage of missing values for the columns:
#                       Count  Percentage
# ActionGrouped       4146079   99.953881
# ActionGranular      4146079   99.953881
# ResourceType        4144998   99.927820
# ThreatFamily        4116614   99.243538
# EmailClusterId      4106285   98.994526
# AntispamDirection   4071481   98.155469
# Roles               4039317   97.380058
# SuspicionLevel      3498157   84.333745
# LastVerdict         3155260   76.067167
# MitreTechniques     2307104   55.619779
# DetectorId                0    0.000000
# IncidentId                0    0.000000
# Id                        0    0.000000
# OrgId                     0    0.000000
# EvidenceRole              0    0.000000
# EntityType                0    0.000000
# Category                  0    0.000000
# IncidentGrade             0    0.000000
# AlertTitle                0    0.000000
# AlertId                   0    0.000000
# Timestamp                 0    0.000000
# DeviceId                  0    0.000000
# AccountName               0    0.000000
# DeviceName                0    0.000000
# IpAddress                 0    0.000000
# Sha256                    0    0.000000
# AccountSid                0    0.000000
# AccountUpn                0    0.000000
# AccountObjectId           0    0.000000
# Url                       0    0.000000
# ApplicationName           0    0.000000
# ApplicationId             0    0.000000
# RegistryValueData         0    0.000000
# RegistryValueName         0    0.000000
# RegistryKey               0    0.000000
# NetworkMessageId          0    0.000000
# FolderPath                0    0.000000
# OAuthApplicationId        0    0.000000
# OSFamily                  0    0.000000
# ResourceIdName            0    0.000000
# FileName                  0    0.000000
# OSVersion                 0    0.000000
# CountryCode               0    0.000000
# State                     0    0.000000
# City                      0    0.000000
# Usage                     0    0.000000

# %%
### Checking for the Distribution of Default ###
import matplotlib.pyplot as plt
# %matplotlib inline
print('Percentage for default\n')
print(round(train_data.IncidentGrade.value_counts(normalize=True)*100,2))
round(train_data.IncidentGrade.value_counts(normalize=True)*100,2).plot(kind='bar')
plt.title('Percentage Distributions by review type')
plt.show()
# Out:
# Percentage for default
#
# IncidentGrade
# BenignPositive    43.43
# TruePositive      35.10
# FalsePositive     21.47
# Name: proportion, dtype: float64

# %%
### Checking for the Distribution of Default ###
import matplotlib.pyplot as plt
# %matplotlib inline
print('Percentage for default\n')
print(round(test_data.IncidentGrade.value_counts(normalize=True)*100,2))
round(test_data.IncidentGrade.value_counts(normalize=True)*100,2).plot(kind='bar')
plt.title('Percentage Distributions by review type')
plt.show()
# Out:
# Percentage for default
#
# IncidentGrade
# BenignPositive    42.26
# TruePositive      35.98
# FalsePositive     21.76
# Name: proportion, dtype: float64

# %%
#correlation

import seaborn as sns
import pandas as pd

# Assuming your data is in a DataFrame called 'train_data'
# Select only numeric columns
numeric_data = train_data.select_dtypes(include=['float64', 'int64'])

# Now calculate and plot the correlation heatmap
sns.heatmap(numeric_data.iloc[:, :10].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Handling Missing Data & encoding**

# %%
train_data = train_data.sample(frac=0.002, random_state=42)
test_data = test_data.sample(frac=0.001, random_state=42)

# %%
test_data = test_data.drop(['Usage'], axis=1)

# %%
train_data = train_data.drop(['Id'], axis=1)
test_data = test_data.drop(['Id'], axis=1)

# %%
train_data = train_data.drop(['MitreTechniques','ActionGrouped', 'ActionGranular', 'EmailClusterId', 'ThreatFamily', 'ResourceType','Roles','AntispamDirection','SuspicionLevel','LastVerdict'], axis=1)
test_data = test_data.drop(['MitreTechniques','ActionGrouped', 'ActionGranular', 'EmailClusterId', 'ThreatFamily', 'ResourceType','Roles','AntispamDirection','SuspicionLevel','LastVerdict'], axis=1)

# %%
train_data = train_data.drop(['AlertId','DeviceId', 'Url','AccountSid', 'AccountUpn', 'AccountObjectId','AccountName','NetworkMessageId', 'RegistryValueName','RegistryValueData','OAuthApplicationId', 'ResourceIdName' ], axis=1)
test_data = test_data.drop(['AlertId','DeviceId', 'Url','AccountSid', 'AccountUpn', 'AccountObjectId','AccountName','NetworkMessageId', 'RegistryValueName','RegistryValueData','OAuthApplicationId', 'ResourceIdName' ], axis=1)

# %%
train_data = train_data.dropna(subset=['IncidentGrade'])
test_data = test_data.dropna(subset=['IncidentGrade'])

# %%
train_data['Timestamp'] = train_data['Timestamp'].str.extract(r'(\d{4}-\d{2}-\d{2})', expand=False)
train_data['Timestamp'] = dd.to_datetime(train_data['Timestamp'], format='%Y-%m-%d')

# %%
test_data['Timestamp'] = test_data['Timestamp'].str.extract(r'(\d{4}-\d{2}-\d{2})', expand=False)
test_data['Timestamp'] = dd.to_datetime(test_data['Timestamp'], format='%Y-%m-%d')

# %%
train_data['Day_of_Week'] = train_data['Timestamp'].dt.day_name()
test_data['Day_of_Week'] = test_data['Timestamp'].dt.day_name()

# %%
train_x = train_data.drop('IncidentGrade', axis=1)
train_y = train_data['IncidentGrade']

# %%
test_x = test_data.drop('IncidentGrade', axis=1)
test_y = test_data['IncidentGrade']

# %%
for col in train_x.columns:
    if train_x[col].dtype == 'object' or train_x[col].dtype == 'string':
        train_x[col] = train_x[col].astype('category')

# %%
for col in test_x.columns:
    if test_x[col].dtype == 'object' or test_x[col].dtype == 'string':
        test_x[col] = test_x[col].astype('category')

# %%
categorical_features = test_x.select_dtypes(include=['category']).columns
categorical_features
# Out:
# Index(['Category', 'EntityType', 'EvidenceRole', 'Day_of_Week'], dtype='object')

# %%
train_x_cat = train_x.astype({col: 'category' for col in categorical_features})
test_x_cat = test_x.astype({col: 'category' for col in categorical_features})

# %%
! pip install dask-ml
# Out:
# Requirement already satisfied: dask-ml in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (2024.4.4)
# Requirement already satisfied: dask-glm>=0.2.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask-ml) (0.3.2)
# Requirement already satisfied: dask>=2.4.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask[array,dataframe]>=2.4.0->dask-ml) (2024.9.1)
# Requirement already satisfied: distributed>=2.4.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask-ml) (2024.9.1)
# Requirement already satisfied: multipledispatch>=0.4.9 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask-ml) (1.0.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask-ml) (0.60.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask-ml) (2.0.1)
# Requirement already satisfied: packaging in c:\users\surenthiran\appdata\roaming\python\python312\site-packages (from dask-ml) (24.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask-ml) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask-ml) (1.5.2)
# Requirement already satisfied: scipy in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask-ml) (1.14.0)
# Requirement already satisfied: click>=8.1 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (2024.9.0)
# Requirement already satisfied: partd>=1.4.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (0.12.1)
# Requirement already satisfied: sparse>=0.7.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask-glm>=0.2.0->dask-ml) (0.15.4)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask[array,dataframe]>=2.4.0->dask-ml) (1.1.15)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from distributed>=2.4.0->dask-ml) (3.1.4)
# Requirement already satisfied: locket>=1.0.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from distributed>=2.4.0->dask-ml) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from distributed>=2.4.0->dask-ml) (1.1.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\surenthiran\appdata\roaming\python\python312\site-packages (from distributed>=2.4.0->dask-ml) (6.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from distributed>=2.4.0->dask-ml) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from distributed>=2.4.0->dask-ml) (3.0.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\surenthiran\appdata\roaming\python\python312\site-packages (from distributed>=2.4.0->dask-ml) (6.4.1)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from distributed>=2.4.0->dask-ml) (2.2.2)
# Requirement already satisfied: zict>=3.0.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from distributed>=2.4.0->dask-ml) (3.0.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from numba>=0.51.0->dask-ml) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\surenthiran\appdata\roaming\python\python312\site-packages (from pandas>=0.24.2->dask-ml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->dask-ml) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->dask-ml) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.2.0->dask-ml) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.2.0->dask-ml) (3.5.0)
# Requirement already satisfied: colorama in c:\users\surenthiran\appdata\roaming\python\python312\site-packages (from click>=8.1->dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (0.4.6)
# Requirement already satisfied: pyarrow>=14.0.1 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from dask-expr<1.2,>=1.1->dask[array,dataframe]>=2.4.0->dask-ml) (17.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.10.3->distributed>=2.4.0->dask-ml) (2.1.5)
# Requirement already satisfied: six>=1.5 in c:\users\surenthiran\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->dask-ml) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dask_ml.preprocessing import DummyEncoder

encoder = DummyEncoder()
train_x = encoder.fit_transform(train_x_cat)
train_x.head()
# Out:
#          OrgId  IncidentId  Timestamp  DetectorId  AlertTitle  Sha256  \
# 8036545     64       49334 2024-06-11          10           8  138268
# 3828916     43       52272 2024-06-13           1           1  138268
# 4404679      2       21863 2024-06-04          18          14  138268
# 8854100     37        3044 2024-06-11          70        1871  138268
# 7977240     22         155 2024-06-06           4           3  138268
#
#          IpAddress  DeviceName  RegistryKey  ApplicationId  ...  \
# 8036545     360606      153085         1631           2251  ...
# 3828916     360606      153085         1631           2251  ...
# 4404679     360606      153085         1631           2251  ...
# 8854100     360606      153085         1631           2251  ...
# 7977240     360606      153085         1631           2251  ...
#
#          EntityType_User  EvidenceRole_Impacted  EvidenceRole_Related  \
# 8036545            False                  False                  True
# 3828916            False                  False                  True
# 4404679            False                   True                 False
# 8854100            False                   True                 False
# 7977240             True                   True                 False
#
#          Day_of_Week_Friday  Day_of_Week_Monday  Day_of_Week_Saturday  \
# 8036545               False               False                 False
# 3828916               False               False                 False
# 4404679               False               False                 False
# 8854100               False               False                 False
# 7977240               False               False                 False
#
#          Day_of_Week_Sunday  Day_of_Week_Thursday  Day_of_Week_Tuesday  \
# 8036545               False                 False                 True
# 3828916               False                  True                False
# 4404679               False                 False                 True
# 8854100               False                 False                 True
# 7977240               False                  True                False
#
#          Day_of_Week_Wednesday
# 8036545                  False
# 3828916                  False
# 4404679                  False
# 8854100                  False
# 7977240                  False
#
# [5 rows x 63 columns]

# %%
for col in train_x.columns:
    if train_x[col].dtype == 'bool':
        train_x[col] = train_x[col].astype(int)

# %%
test_x = encoder.transform(test_x_cat)
test_x.head()
# Out:
#          OrgId  IncidentId  Timestamp  DetectorId  AlertTitle  Sha256  \
# 2480092    378         783 2024-06-08           1           1  138268
# 437473     613        3036 2024-06-06         838         465  138268
# 3166255    113       24609 2024-06-09           1           1  138268
# 2264349     35         210 2024-06-03           0           0  138268
# 808028      40      210245 2024-06-14           2           2  138268
#
#          IpAddress  DeviceName  RegistryKey  ApplicationId  ...  \
# 2480092     360606      153085         1631           2251  ...
# 437473      360606      153085         1631           2251  ...
# 3166255     360606      153085         1631           2251  ...
# 2264349         31      153085         1631           2251  ...
# 808028      360606       13775         1631           2251  ...
#
#          EntityType_User  EvidenceRole_Impacted  EvidenceRole_Related  \
# 2480092            False                   True                 False
# 437473              True                   True                 False
# 3166255            False                  False                  True
# 2264349            False                  False                  True
# 808028             False                   True                 False
#
#          Day_of_Week_Friday  Day_of_Week_Monday  Day_of_Week_Saturday  \
# 2480092               False               False                  True
# 437473                False               False                 False
# 3166255               False               False                 False
# 2264349               False                True                 False
# 808028                 True               False                 False
#
#          Day_of_Week_Sunday  Day_of_Week_Thursday  Day_of_Week_Tuesday  \
# 2480092               False                 False                False
# 437473                False                  True                False
# 3166255                True                 False                False
# 2264349               False                 False                False
# 808028                False                 False                False
#
#          Day_of_Week_Wednesday
# 2480092                  False
# 437473                   False
# 3166255                  False
# 2264349                  False
# 808028                   False
#
# [5 rows x 63 columns]

# %%
for col in test_x.columns:
    if test_x[col].dtype == 'bool':
        test_x[col] = test_x[col].astype(int)

# %%
test_x.head()
# Out:
#          OrgId  IncidentId  Timestamp  DetectorId  AlertTitle  Sha256  \
# 2480092    378         783 2024-06-08           1           1  138268
# 437473     613        3036 2024-06-06         838         465  138268
# 3166255    113       24609 2024-06-09           1           1  138268
# 2264349     35         210 2024-06-03           0           0  138268
# 808028      40      210245 2024-06-14           2           2  138268
#
#          IpAddress  DeviceName  RegistryKey  ApplicationId  ...  \
# 2480092     360606      153085         1631           2251  ...
# 437473      360606      153085         1631           2251  ...
# 3166255     360606      153085         1631           2251  ...
# 2264349         31      153085         1631           2251  ...
# 808028      360606       13775         1631           2251  ...
#
#          EntityType_User  EvidenceRole_Impacted  EvidenceRole_Related  \
# 2480092                0                      1                     0
# 437473                 1                      1                     0
# 3166255                0                      0                     1
# 2264349                0                      0                     1
# 808028                 0                      1                     0
#
#          Day_of_Week_Friday  Day_of_Week_Monday  Day_of_Week_Saturday  \
# 2480092                   0                   0                     1
# 437473                    0                   0                     0
# 3166255                   0                   0                     0
# 2264349                   0                   1                     0
# 808028                    1                   0                     0
#
#          Day_of_Week_Sunday  Day_of_Week_Thursday  Day_of_Week_Tuesday  \
# 2480092                   0                     0                    0
# 437473                    0                     1                    0
# 3166255                   1                     0                    0
# 2264349                   0                     0                    0
# 808028                    0                     0                    0
#
#          Day_of_Week_Wednesday
# 2480092                      0
# 437473                       0
# 3166255                      0
# 2264349                      0
# 808028                       0
#
# [5 rows x 63 columns]

# %% [markdown]
# ## **SMOTE**

# %%
! pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (0.12.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (2.0.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.14.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from imbalanced-learn) (3.5.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE

# %%
combined_df = dd.concat([train_x, train_y], axis=1)

# %%
combined_df_test = dd.concat([test_x, test_y], axis=1)

# %%
def apply_smote(chunk):
    smote = SMOTE()
    #Exclude datetime columns from X
    X = chunk.select_dtypes(exclude=['datetime']).drop('IncidentGrade', axis=1)
    y = chunk['IncidentGrade']
    X_resampled, y_resampled = smote.fit_resample(X, y)
    return pd.concat([X_resampled, y_resampled], axis=1)

# %%
# Apply SMOTE on each chunk
meta = pd.DataFrame(columns=[col for col in combined_df.columns if col != 'Timestamp'])
resampled_chunks = combined_df.map_partitions(apply_smote, meta=meta)

# %%
resampled_df = dd.concat([resampled_chunks], axis=0)

# %% [markdown]
# ## **split into train and test for Evaluation**

# %%
# split resampled data into train_x and y
train_x = resampled_df.drop('IncidentGrade', axis=1)
train_y = resampled_df['IncidentGrade']

# %%
test_x = combined_df_test.drop('IncidentGrade', axis=1)
test_y = combined_df_test['IncidentGrade']

# %%
test_x = test_x.drop('Timestamp', axis=1)

# %%
mapping = {'FalsePositive': 0.0, 'TruePositive': 1.0, 'BenignPositive': 2.0}

# %%
train_y = train_y.map(mapping, meta=('IncidentGrade', 'float64'))

# %%
test_y = test_y.map(mapping, meta=('IncidentGrade', 'float64'))

# %%
train_x = train_x.astype(np.float64)  # Convert train_x and test_x to float64

test_x = test_x.astype(np.float64)

# %% [markdown]
# - due to taking sample sizes in the test and train data these two columns are not in test data, so we dropped these now,but when training the whole data this won't be a problem and we can add these columns that time.

# %%
train_x = train_x.drop(['EntityType_blob'], axis=1, errors='ignore')

# %%
train_x = train_x.drop('EntityType_MailboxConfiguration', axis=1,errors='ignore')

# %% [markdown]
# - let's convert the train and test dask dataframe to array before training, because the model accepts the array.

# %%
train_x = train_x.to_dask_array(lengths=True)
test_x = test_x.to_dask_array(lengths=True)

# %%
test_y = test_y.to_dask_array(lengths=True)
train_y = train_y.to_dask_array(lengths=True)

# %% [markdown]
# # **Models**

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from dask_ml.wrappers import ParallelPostFit
from dask_ml.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression

# %%
models = {
    'Logistic Regression': ParallelPostFit(estimator=LogisticRegression()),
    'Random Forest': ParallelPostFit(estimator=RandomForestClassifier()),
    'Decision Tree': ParallelPostFit(estimator=DecisionTreeClassifier()),
    'XGBoost': ParallelPostFit(estimator=XGBClassifier(use_label_encoder=False, eval_metric='logloss'))
}

# %%
for name, model in models.items():
    print(f"Evaluating {name}...")
    model.fit(train_x, train_y)
    score = model.score(test_x, test_y)
    print(f"{name} Accuracy score: {score}")
# Out:
# Evaluating Logistic Regression...
# Logistic Regression Accuracy score: 0.4713114754098361
# Evaluating Random Forest...
# Random Forest Accuracy score: 0.7967695274831244
# Evaluating Decision Tree...
# Decision Tree Accuracy score: 0.8146094503375121
# Evaluating XGBoost...
# XGBoost Accuracy score: 0.8382352941176471

# %% [markdown]
# ## **Hyper Parameter Tuning**

# %%
from scipy.stats import randint

# %%
param_dist = {
    "max_depth": [1, 2, 3, None],
    "n_estimators": [100, 200, 300, 400, 500, 600],
    "learning_rate": [0.01, 0.1, 0.2, 0.25, 0.3, 0.35, 0.4],
}

# %%
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# %%
Grid_search = GridSearchCV(estimator=model, param_grid=param_dist, cv=5, scoring='accuracy')

Grid_search.fit(train_x, train_y)

print(f"Best parameters: {Grid_search.best_params_}")
print(f"Best score: {Grid_search.best_score_}")
# Out:
# Best parameters: {'learning_rate': 0.35, 'max_depth': None, 'n_estimators': 600}
# Best score: 0.872302896053819

# %% [markdown]
# ## **Model Initialization and Fitting**

# %%
! pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (2.0.1)
# Requirement already satisfied: scipy in c:\users\surenthiran\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.14.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from xgboost import XGBClassifier
from dask_ml.wrappers import ParallelPostFit

# %%
xgmodel = ParallelPostFit(estimator=XGBClassifier(use_label_encoder=False, eval_metric='logloss'))

# %%
xgmodel.fit(train_x, train_y)
# Out:
# ParallelPostFit(estimator=XGBClassifier(base_score=None, booster=None,
#                                         callbacks=None, colsample_bylevel=None,
#                                         colsample_bynode=None,
#                                         colsample_bytree=None, device=None,
#                                         early_stopping_rounds=None,
#                                         enable_categorical=False,
#                                         eval_metric='logloss',
#                                         feature_types=None, gamma=None,
#                                         grow_policy=None, importance_type=None,
#                                         interaction_constraints=None,
#                                         learning_rate=None, max_bin=None,
#                                         max_cat_threshold=None,
#                                         max_cat_to_onehot=None,
#                                         max_delta_step=None, max_depth=None,
#                                         max_leaves=None, min_child_weight=None,
#                                         missing=nan, monotone_constraints=None,
#                                         multi_strategy=None, n_estimators=None,
#                                         n_jobs=None, num_parallel_tree=None,
#                                         objective='multi:softprob', ...))

# %% [markdown]
# # **Predict the Test Data with the Model**

# %%
predictions = xgmodel.predict(test_x)

# %% [markdown]
# ## **Final Project Evaluation Report of Precision, Recall, macro-f1-score and overall accuracy**

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
print(classification_report(test_y, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.78      0.78       861
#          1.0       0.89      0.83      0.86      1525
#          2.0       0.83      0.88      0.86      1762
#
#     accuracy                           0.84      4148
#    macro avg       0.83      0.83      0.83      4148
# weighted avg       0.84      0.84      0.84      4148
